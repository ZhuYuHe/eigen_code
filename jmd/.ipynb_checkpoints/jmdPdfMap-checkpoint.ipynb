# %%
from pdfextractor import extractor
import pdfextractor
import pickle
import jieba
import pandas as pd
import re
import requests
import operator

# %%
class jmdPDFMap(object):
    """
    根据pdf生成文章，并计算推荐的准确率和召回率
    意图：导语，业绩变动原因，主营业务$业务进展，未来计划
    """
    def __init__(self):
        self.labels = ['导语', '业绩变动原因', '主营业务$业务进展', '未来计划', 'other']
        self.prop = [0.2, 0.2, 0.4, 0.3, 0]
        self.K = 0
        #每个意图对应的句子或段落数量
        self.num = {}
        self.recommendList = []
        
        
    def computePR(self, article, textList = None, pdfurl = None, mode = 'para'):
        """
        pdfurl和textList为内容来源，必须有且仅有一个为None
        mode 必须指明
        """
        if ((pdfurl is None) and (textList is None)) or ((not pdfurl is None) and (not textList is None)):
            raise("pdfurl and textList can't be None or be 'NOT NONE' Simultaneously ")
        intentList = []
        #article_sen = self.get_article_sentence(article)
        article_sen = article
        article_len = len(article_sen)
        if article_len == 0:
            return -1, -1
        print 'article length: ' + str(article_len)
        if not pdfurl is None:
            if mode == 'para':
                try:
                    pdftext = self.extractPDF(pdfurl, 0.8, ['para'])
                except BaseException:
                    return -1, -1
            else:
                try:
                    pdftext = self.extractPDF(pdfurl, 0.8, ['text'])
                except BaseException:
                    return -1, -1
        else:
            pdftext = textList
        for t in pdftext:
            intentList.append(self.getIntent(t))
        if mode == 'para':
            self.K = int(len(article_sen) * 0.5)
        else:
            self.K = int(len(article_sen) * 1.5)
        for l in range(len(self.labels)):
            self.num[self.labels[l]] = int(self.K * self.prop[l])
        self.recommendList = self.getTopKintent(intentList)
        rec_len = len(self.recommendList)
        if rec_len == 0:
            return -1, -1
        print 'recomment list length: ' + str(rec_len)
        P_dic = {}
        Pcount = 0
        Rcount = 0
        for r in self.recommendList:
            P_dic[r] = False
        for sen in article_sen:
            for rec in self.recommendList:
                if self.MatchTwoText(sen, rec):
                    Rcount += 1
                    if P_dic[rec] is False:
                        P_dic[rec] = True
                        Pcount += 1
                    break
        P = Pcount * 1.0 / rec_len
        R = Rcount * 1.0 / article_len
        print 'Pcount: ' + str(Pcount)
        print 'Rcount: ' + str(Rcount)
        return P, R
    
    def getRec(self):
        return self.recommendList
        
    def getTopKintent(self, intentlist):
        intent = {}
        for l in self.labels:
            intent[l] = {}
        
        for i in intentlist:
            key = i['intent']
            intent[key][i['content']] = i['prob']
        result = []
        for l in self.labels:
            intent_l = intent[l]
            intent[l] = sorted(intent_l.items(), key=operator.itemgetter(1))
        print "各个段落（句子）的预测意图分布为："
        for i in intent:
            print i + "  " + str(len(intent[i]))
        for l in intent.keys():
            result.extend([d[0] for d in intent[l][:self.num[l]]])
        return result
        
    def get_article_sentence(self, ar):
        """
        given an article, return the list of sentences
        """
        textList = ar.encode('utf-8').split('。') 
        textList = [t.replace('\n', '') for t in textList]
        textList = filter(lambda x: x != '', textList)
        return textList

    #percent: 取pdf的前多少页
    def extractPDF(self, pdfPath, percent, source = ['table', 'text', 'para']):
        savePath = '/home/zhuyuhe/mydata/jmd/percent/'
        ex = extractor.StockFinanceExtractor(pdfPath, percent)

        nodes = ex.get_pdf_objects(filter_headline=True)

        paraList = []
        textList = []
        textNodes = []
        tableList = []
        tableNodes = []
        senList = []
        for node in nodes:
            if isinstance(node.obj, pdfextractor.pdftree.VirtualNode):
                continue
            if isinstance(node.obj, pdfextractor.page.Table):
                tableNodes.append(node)
            elif  not isinstance(node.obj, pdfextractor.page.Catalog):
                textNodes.append(node)
        if 'table' in source:
            tableList = self.get_node_texts(tableNodes)
            tableList = [t.replace('|', '').split('\n') for t in tableList]
            #二维数组转化为一维
            tableList = sum(tableList,[])
        textList = self.get_node_texts(textNodes)
        if 'para' in source:
            paraList = [t.replace('\n', '') for t in textList]
            paraList = filter(lambda x: x != '', paraList)
        elif 'text' in source:
            senList = sum([t.encode('utf-8').split('。') for t in textList],[])
            senList = [t.replace('\n', '') for t in senList]
            senList = filter(lambda x: x != '', senList)

        pdf = []
    #     pdf.append(textList)
    #     pdf.append(tableList)
    #     pdf = sum(pdf, [])
#         print pdf
        pdf.extend(senList)
#         print 'after extent senList: ' + str(pdf) 
        pdf.extend(tableList)
#         print 'after extent tableList: ' + str(pdf) 
        pdf.extend(paraList)
#         print 'after extent paraList: ' + str(pdf) 
        print 'pdflist length: ' + str(len(pdf))

        return pdf
    
    def get_node_texts(self, pdf_nodes):
        '''
        Given a list of nodes, get the texts of these nodes
        '''
        texts = []
        for node in pdf_nodes:
            text = node.obj.get_text()
            if len(text) <= 25:
                continue
            if u'□' in text or u'√' in text:
                continue
            texts.append(text)
        return texts
    
    def getIntent(self, text):
        """
        return intent of the given text
        """
        result = {}
        query = requests.post("https://surreal.aidigger.com/api/v1/classification/intent/finance/0",json={ "query": text}).json()
        predict = query['predict']
        prob = [x['prob'] for x in predict]
        i = max(prob)
        intent = predict[prob.index(i)]['name']
        #print intent
        result['content'] = text
        result['intent'] = self.intentMap(intent)
        result['prob'] = i
        return result
    
    def intentMap(self, i):
        """
        将现有意图映射到芥末堆所给的意图上去
        """
        i = i.encode('utf-8')
        if i == '意图_企业业绩__现状偏好' or i == '意图_企业业绩__现状偏坏' or i == '导语' or i == '意图_企业基本信息介绍_企业基本信息介绍':
            return self.labels[0]
        elif '原因' in i:
            return self.labels[1]
        elif '业务' in i and not '前景' in i:
            return self.labels[2]
        elif '前景' in i or '评论' in i:
            return self.labels[3]
        else:
            return self.labels[4]
        
    def MatchTwoText(self, t1, t2, threshold = 0.5):
        """
        检查两个句子是否匹配
        """
        ct1 = ' '.join(jieba.cut(t1)).split()
        ct2 = ' '.join(jieba.cut(t2)).split()
        commonL = set(ct1).intersection(set(ct2)).__len__()
        if commonL * 1.0 / set(ct1).__len__() > threshold:
            return True
        return False

    def splitByPeriod(self, P):
        """
        split paragraph to sentences
        """
        senList = sum([t.encode('utf-8').split('。') for t in P],[])
        senList = [t.replace('\n', '') for t in senList]
        senList = filter(lambda x: x != '', senList)
        return senList

# %%
jmdata_mapping = pickle.load(open('/home/zhuyuhe/mydata/jmd/percent/jmd_pdf_mapping2.pkl', 'rb'))[2:]
a = jmdPDFMap()
P_para = []
R_para = []
P_sen = []
R_sen = []
i = 0
for jmap in jmdata_mapping:
    print '******************************************************'
    print 'article ' + str(i) + ' :'
    print '--------------------'
    P,R = a.computePR(jmap['content'], jmap['pdf_url'], 'para')
    P_para.append(P)
    R_para.append(R)
    print "--PARA--  Pecision: " + str(P) + "    Recall: " + str(R)
    print '--------------------'
    P,R = a.computePR(jmap['content'], jmap['pdf_url'], 'sentence')
    P_sen.append(P)
    R_sen.append(R)
    print "--SEN--  Pecision: " + str(P) + "    Recall: " + str(R)
    print '---------------------'
    print '*******************************************************'
    i += 1
#print a.getIntent('前三季度利润为0，同比下降5%')['intent']

# jmap = jmd_mapping[0]
# print a.computePR(jmap['content'], jmap['pdf_url'], 'sentence')

# %%
a = jmdPDFMap()
for jmap in jmdata_mapping[14:]:
    print '******************************************************'
    print 'article ' + str(i) + ' :'
    print '--------------------'
    P,R = a.computePR(jmap['content'], jmap['pdf_url'], 'para')
    P_para.append(P)
    R_para.append(R)
    print "--PARA--  Pecision: " + str(P) + "    Recall: " + str(R)
    print '--------------------'
    P,R = a.computePR(jmap['content'], jmap['pdf_url'], 'sentence')
    P_sen.append(P)
    R_sen.append(R)
    print "--SEN--  Pecision: " + str(P) + "    Recall: " + str(R)
    print '---------------------'
    print '*******************************************************'
    i += 1

# %%
print 'P_para: ' + str(P_para)
print 'R_para: ' + str(R_para)
print 'P_sen: ' + str(P_sen)
print 'R_sen: ' + str(R_sen) 
print len(P_para)

# %%
i = 0
jmdata_map = {}
P_para2 = []
P_sen2 = []
R_para2 = []
R_sen2 = []
jmdata_mapping = pickle.load(open('/home/zhuyuhe/mydata/jmd/percent/jmd_pdf_mapping2.pkl', 'rb'))[2:]
a = jmdPDFMap()
for jmap in jmdata_mapping:
    key = jmap['pdf_url']
    try:
        para = a.extractPDF(jmap['pdf_url'], 0.5, 'para')
    except BaseException:
        continue
    jmdata_map[key] = {}
    content = a.get_article_sentence(jmap['content'])
    sen = a.splitByPeriod(para)
    jmdata_map[key]['content'] = content
    jmdata_map[key]['para'] = para
    jmdata_map[key]['sen'] = sen
    print '---' + key + ' done' + '----'
    i+=1
# Out:
# Pdfminer Parsed time: 39s
# Construct Pdf Tree time: 0s
# pdflist length: 182
# ---http://www.cninfo.com.cn/finalpage/2017-06-20/1203635303.PDF done----
# Download pdf time: 7s
# download http status code: 200
# Pdfminer Parsed time: 36s
# Construct Pdf Tree time: 0s
# pdflist length: 166
# ---http://disclosure.szse.cn/finalpage/2017-04-11/1203274908.PDF done----
# Download pdf time: 2s
# download http status code: 200
# Pdfminer Parsed time: 17s
# Construct Pdf Tree time: 0s
# pdflist length: 46
# ---http://www.cninfo.com.cn/finalpage/2017-07-26/1203737887.PDF done----
# Download pdf time: 6s
# download http status code: 200
# Pdfminer Parsed time: 35s
# Construct Pdf Tree time: 0s
# pdflist length: 86
# ---http://disclosure.szse.cn/finalpage/2017-08-25/1203872097.PDF done----
# Download pdf time: 1s
# download http status code: 200
# Pdfminer Parsed time: 6s
# Construct Pdf Tree time: 0s
# pdflist length: 11
# ---http://disclosure.szse.cn/finalpage/2016-10-18/1202765393.PDF done----
# Download pdf time: 1s
# download http status code: 200
# Pdfminer Parsed time: 34s
# Construct Pdf Tree time: 0s
# pdflist length: 179
# ---http://www.cninfo.com.cn/finalpage/2017-05-10/1203508904.PDF done----
# Download pdf time: 2s
# download http status code: 200
# Pdfminer Parsed time: 66s
# Download pdf time: 5s
# download http status code: 200
# Pdfminer Parsed time: 32s
# Construct Pdf Tree time: 0s
# pdflist length: 124
# ---http://www.cninfo.com.cn/finalpage/2017-04-19/1203340942.PDF done----
# Download pdf time: 1s
# download http status code: 200
# Pdfminer Parsed time: 9s
# Construct Pdf Tree time: 0s
# pdflist length: 11
# ---http://disclosure.szse.cn/finalpage/2016-10-18/1202763826.PDF done----
# Download pdf time: 0s
# download http status code: 200
# Pdfminer Parsed time: 6s
# Construct Pdf Tree time: 0s
# pdflist length: 37
# ---http://static.sse.com.cn/disclosure/listedinfo/announcement/c/2017-04-29/600730_2017_1.pdf done----
# Download pdf time: 1s
# download http status code: 200
# Pdfminer Parsed time: 5s
# Construct Pdf Tree time: 0s
# pdflist length: 36
# ---http://disclosure.szse.cn/finalpage/2016-10-25/1202780794.PDF done----
# Download pdf time: 1s
# download http status code: 200
# Pdfminer Parsed time: 14s
# Construct Pdf Tree time: 0s
# pdflist length: 19
# ---http://disclosure.szse.cn/finalpage/2016-10-27/1202793355.PDF done----
# Download pdf time: 2s
# download http status code: 200
# Pdfminer Parsed time: 37s
# Construct Pdf Tree time: 0s
# pdflist length: 126
# ---http://disclosure.szse.cn/finalpage/2017-04-25/1203379575.PDF done----
# Download pdf time: 1s
# download http status code: 200
# Pdfminer Parsed time: 3s
# Construct Pdf Tree time: 0s
# pdflist length: 5
# ---http://disclosure.szse.cn/finalpage/2016-04-30/1202283035.PDF done----
# Download pdf time: 3s
# download http status code: 200
# Pdfminer Parsed time: 58s
# Construct Pdf Tree time: 0s
# pdflist length: 103
# ---http://disclosure.szse.cn/finalpage/2017-07-28/1203739610.PDF done----
# Download pdf time: 2s
# download http status code: 200
# Pdfminer Parsed time: 35s
# Download pdf time: 1s
# download http status code: 200
# Pdfminer Parsed time: 5s

# %%
a = jmdPDFMap()
for key in jmdata_map.keys():
    print key  
    print '---------PARA-----------'
    P,R = a.computePR(jmdata_map[key]['content'], textList=jmdata_map[key]['para'], mode = 'para')
    P_para2.append(P)
    R_para2.append(R)
    print "Pecision: " + str(P) + "    Recall: " + str(R)
    print '---------SEN-------------'
    P,R = a.computePR(jmdata_map[key]['content'], textList=jmdata_map[key]['sen'], mode = 'sen')
    P_sen2.append(P)
    R_sen2.append(R)
    print "Pecision: " + str(P) + "    Recall: " + str(R)
    print '*******************************************************'

# %%
Ppara = P_para2
Rpara = R_para2
Psen = P_sen2
R_sen = R_sen2

# %%
print 1

# %% [raw]
# article 33
# ---------PARA-----------
# article length: 17
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  56
# 导语  1
# other  295
# 业绩变动原因  6
# 未来计划  25
# recomment list length: 7
# Pcount: 1
# Rcount: 4
# Pecision: 0.142857142857    Recall: 0.235294117647
# ---------SEN-------------
# article length: 17
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  113
# 导语  1
# other  465
# 业绩变动原因  13
# 未来计划  53
# recomment list length: 23
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# *******************************************************
# article 7
# ---------PARA-----------
# article length: 11
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  40
# 导语  1
# other  301
# 业绩变动原因  6
# 未来计划  26
# recomment list length: 5
# Pcount: 1
# Rcount: 1
# Pecision: 0.2    Recall: 0.0909090909091
# ---------SEN-------------
# article length: 11
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  70
# 导语  1
# other  493
# 业绩变动原因  10
# 未来计划  51
# recomment list length: 14
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# *******************************************************
# article 6
# ---------PARA-----------
# article length: 21
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  36
# 导语  0
# other  395
# 业绩变动原因  7
# 未来计划  62
# recomment list length: 9
# Pcount: 2
# Rcount: 4
# Pecision: 0.222222222222    Recall: 0.190476190476
# ---------SEN-------------
# article length: 21
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  74
# 导语  0
# other  590
# 业绩变动原因  12
# 未来计划  109
# recomment list length: 27
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# *******************************************************
# article 5
# ---------PARA-----------
# article length: 10
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  0
# 导语  0
# other  5
# 业绩变动原因  1
# 未来计划  0
# recomment list length: 1
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# ---------SEN-------------
# article length: 10
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  0
# 导语  0
# other  5
# 业绩变动原因  1
# 未来计划  0
# recomment list length: 1
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# *******************************************************
# article 4
# ---------PARA-----------
# article length: 10
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  1
# 导语  0
# other  199
# 业绩变动原因  0
# 未来计划  6
# recomment list length: 2
# Pcount: 2
# Rcount: 2
# Pecision: 1.0    Recall: 0.2
# ---------SEN-------------
# article length: 10
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  27
# 导语  1
# other  603
# 业绩变动原因  5
# 未来计划  48
# recomment list length: 14
# Pcount: 2
# Rcount: 2
# Pecision: 0.142857142857    Recall: 0.2
# *******************************************************
# article 3
# ---------PARA-----------
# article length: 19
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  61
# 导语  1
# other  388
# 业绩变动原因  4
# 未来计划  26
# recomment list length: 7
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# ---------SEN-------------
# article length: 19
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  125
# 导语  3
# other  575
# 业绩变动原因  9
# 未来计划  59
# recomment list length: 27
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# *******************************************************
# article 2
# ---------PARA-----------
# article length: 12
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  0
# 导语  0
# other  12
# 业绩变动原因  0
# 未来计划  0
# Pecision: -1    Recall: -1
# ---------SEN-------------
# article length: 12
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  0
# 导语  0
# other  14
# 业绩变动原因  0
# 未来计划  0
# Pecision: -1    Recall: -1
# *******************************************************
# article 1
# ---------PARA-----------
# article length: 13
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  0
# 导语  0
# other  6
# 业绩变动原因  0
# 未来计划  1
# recomment list length: 1
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# ---------SEN-------------
# article length: 13
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  0
# 导语  0
# other  9
# 业绩变动原因  0
# 未来计划  3
# recomment list length: 3
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# *******************************************************
# article 0
# ---------PARA-----------
# article length: 12
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  4
# 导语  0
# other  11
# 业绩变动原因  4
# 未来计划  3
# recomment list length: 4
# Pcount: 2
# Rcount: 8
# Pecision: 0.5    Recall: 0.666666666667
# ---------SEN-------------
# article length: 12
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  13
# 导语  1
# other  18
# 业绩变动原因  19
# 未来计划  6
# recomment list length: 16
# Pcount: 3
# Rcount: 3
# Pecision: 0.1875    Recall: 0.25
# *******************************************************
# article 32
# ---------PARA-----------
# article length: 22
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  11
# 导语  0
# other  219
# 业绩变动原因  1
# 未来计划  13
# recomment list length: 8
# Pcount: 1
# Rcount: 3
# Pecision: 0.125    Recall: 0.136363636364
# ---------SEN-------------
# article length: 22
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  22
# 导语  0
# other  311
# 业绩变动原因  3
# 未来计划  23
# recomment list length: 25
# Pcount: 4
# Rcount: 5
# Pecision: 0.16    Recall: 0.227272727273
# *******************************************************
# article 9
# ---------PARA-----------
# article length: 26
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  19
# 导语  1
# other  211
# 业绩变动原因  2
# 未来计划  41
# recomment list length: 11
# Pcount: 3
# Rcount: 3
# Pecision: 0.272727272727    Recall: 0.115384615385
# ---------SEN-------------
# article length: 26
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  54
# 导语  2
# other  332
# 业绩变动原因  7
# 未来计划  84
# recomment list length: 35
# Pcount: 1
# Rcount: 1
# Pecision: 0.0285714285714    Recall: 0.0384615384615
# *******************************************************
# article 8
# ---------PARA-----------
# article length: 13
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  7
# 导语  0
# other  391
# 业绩变动原因  12
# 未来计划  18
# recomment list length: 4
# Pcount: 2
# Rcount: 4
# Pecision: 0.5    Recall: 0.307692307692
# ---------SEN-------------
# article length: 13
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  23
# 导语  1
# other  606
# 业绩变动原因  15
# 未来计划  37
# recomment list length: 16
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# *******************************************************
# article 17
# ---------PARA-----------
# article length: 14
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  6
# 导语  0
# other  21
# 业绩变动原因  11
# 未来计划  0
# recomment list length: 3
# Pcount: 1
# Rcount: 2
# Pecision: 0.333333333333    Recall: 0.142857142857
# ---------SEN-------------
# article length: 14
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  6
# 导语  1
# other  30
# 业绩变动原因  12
# 未来计划  1
# recomment list length: 12
# Pcount: 5
# Rcount: 5
# Pecision: 0.416666666667    Recall: 0.357142857143
# *******************************************************
# article 16
# ---------PARA-----------
# article length: 18
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  0
# 导语  0
# other  25
# 业绩变动原因  15
# 未来计划  0
# recomment list length: 1
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# ---------SEN-------------
# article length: 18
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  1
# 导语  0
# other  40
# 业绩变动原因  15
# 未来计划  2
# recomment list length: 8
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# *******************************************************
# article 15
# ---------PARA-----------
# article length: 8
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  0
# 导语  0
# other  5
# 业绩变动原因  5
# 未来计划  1
# recomment list length: 1
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# ---------SEN-------------
# article length: 8
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  0
# 导语  0
# other  5
# 业绩变动原因  5
# 未来计划  1
# recomment list length: 3
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# *******************************************************
# article 14
# ---------PARA-----------
# article length: 12
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  40
# 导语  1
# other  231
# 业绩变动原因  2
# 未来计划  28
# recomment list length: 5
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# ---------SEN-------------
# article length: 12
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  77
# 导语  2
# other  366
# 业绩变动原因  2
# 未来计划  55
# recomment list length: 16
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# *******************************************************
# article 13
# ---------PARA-----------
# article length: 27
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  46
# 导语  1
# other  204
# 业绩变动原因  3
# 未来计划  43
# recomment list length: 11
# Pcount: 1
# Rcount: 1
# Pecision: 0.0909090909091    Recall: 0.037037037037
# ---------SEN-------------
# article length: 27
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  137
# 导语  4
# other  319
# 业绩变动原因  4
# 未来计划  91
# recomment list length: 36
# Pcount: 1
# Rcount: 1
# Pecision: 0.0277777777778    Recall: 0.037037037037
# *******************************************************
# article 12
# ---------PARA-----------
# article length: 7
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  0
# 导语  0
# other  8
# 业绩变动原因  5
# 未来计划  1
# Pecision: -1    Recall: -1
# ---------SEN-------------
# article length: 7
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  0
# 导语  0
# other  9
# 业绩变动原因  8
# 未来计划  1
# recomment list length: 3
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# *******************************************************
# article 11
# ---------PARA-----------
# article length: 12
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  27
# 导语  0
# other  106
# 业绩变动原因  0
# 未来计划  11
# recomment list length: 3
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# ---------SEN-------------
# article length: 12
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  56
# 导语  0
# other  287
# 业绩变动原因  3
# 未来计划  24
# recomment list length: 15
# Pcount: 1
# Rcount: 3
# Pecision: 0.0666666666667    Recall: 0.25
# *******************************************************
# article 10
# ---------PARA-----------
# article length: 8
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  10
# 导语  1
# other  48
# 业绩变动原因  19
# 未来计划  13
# recomment list length: 2
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# ---------SEN-------------
# article length: 8
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  33
# 导语  1
# other  55
# 业绩变动原因  22
# 未来计划  22
# recomment list length: 10
# Pcount: 1
# Rcount: 1
# Pecision: 0.1    Recall: 0.125
# *******************************************************
# article 35
# ---------PARA-----------
# article length: 11
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  5
# 导语  0
# other  13
# 业绩变动原因  12
# 未来计划  4
# recomment list length: 4
# Pcount: 2
# Rcount: 3
# Pecision: 0.5    Recall: 0.272727272727
# ---------SEN-------------
# article length: 11
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  9
# 导语  1
# other  30
# 业绩变动原因  21
# 未来计划  7
# recomment list length: 14
# Pcount: 4
# Rcount: 4
# Pecision: 0.285714285714    Recall: 0.363636363636
# *******************************************************
# article 34
# ---------PARA-----------
# article length: 12
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  48
# 导语  0
# other  348
# 业绩变动原因  17
# 未来计划  45
# recomment list length: 4
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# ---------SEN-------------
# article length: 12
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  96
# 导语  3
# other  513
# 业绩变动原因  24
# 未来计划  93
# recomment list length: 18
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# *******************************************************
# article 31
# ---------PARA-----------
# article length: 18
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  30
# 导语  2
# other  218
# 业绩变动原因  8
# 未来计划  31
# recomment list length: 7
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# ---------SEN-------------
# article length: 18
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  55
# 导语  2
# other  434
# 业绩变动原因  11
# 未来计划  60
# recomment list length: 25
# Pcount: 2
# Rcount: 2
# Pecision: 0.08    Recall: 0.111111111111
# *******************************************************
# article 30
# ---------PARA-----------
# article length: 13
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  18
# 导语  3
# other  142
# 业绩变动原因  8
# 未来计划  15
# recomment list length: 5
# Pcount: 1
# Rcount: 1
# Pecision: 0.2    Recall: 0.0769230769231
# ---------SEN-------------
# article length: 13
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  43
# 导语  3
# other  213
# 业绩变动原因  12
# 未来计划  31
# recomment list length: 18
# Pcount: 2
# Rcount: 2
# Pecision: 0.111111111111    Recall: 0.153846153846
# *******************************************************
# article 19
# ---------PARA-----------
# article length: 13
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  10
# 导语  0
# other  344
# 业绩变动原因  5
# 未来计划  43
# recomment list length: 4
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# ---------SEN-------------
# article length: 13
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  33
# 导语  0
# other  542
# 业绩变动原因  10
# 未来计划  95
# recomment list length: 15
# Pcount: 0
# Rcount: 0
# Pecision: 0.0    Recall: 0.0
# *******************************************************
# article 18
# ---------PARA-----------
# article length: 21
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  1
# 导语  1
# other  17
# 业绩变动原因  0
# 未来计划  4
# recomment list length: 5
# Pcount: 2
# Rcount: 5
# Pecision: 0.4    Recall: 0.238095238095
# ---------SEN-------------
# article length: 21
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  4
# 导语  2
# other  23
# 业绩变动原因  1
# 未来计划  7
# recomment list length: 14
# Pcount: 4
# Rcount: 4
# Pecision: 0.285714285714    Recall: 0.190476190476
# *******************************************************
# article 28
# ---------PARA-----------
# article length: 17
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  6
# 导语  1
# other  96
# 业绩变动原因  3
# 未来计划  3
# recomment list length: 7
# Pcount: 5
# Rcount: 14
# Pecision: 0.714285714286    Recall: 0.823529411765
# ---------SEN-------------
# article length: 17
# 各个段落（句子）的预测意图分布为：
# 主营业务$业务进展  16
# 导语  2
# other  320
# 业绩变动原因  16
# 未来计划  21
# recomment list length: 24
# Pcount: 5
# Rcount: 6
# Pecision: 0.208333333333    Recall: 0.352941176471
# *******************************************************
